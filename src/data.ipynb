# %%
import pandas as pd

df = pd.read_csv("../data/apass_x_galex.csv")
df.shape
# Out:
# (283950, 70)

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (244844, 70)

# %%
df.loc[:, ["RAJ2000","DEJ2000"]].to_csv("../data/coord.csv", index=False, header=False)

# %%
df.head()
# Out:
#     angDist     RAJ2000    DEJ2000  errHalfMaj  errHalfMin  errPosAng  \
# 0  0.080104    0.552242 -24.815117       0.256       0.214         90
# 2  0.823984    0.584588 -24.744407       0.359       0.227          0
# 3  0.615344  355.008743 -26.685271       0.859       0.538          0
# 4  0.101990    1.549189 -21.103651       0.718       0.571         90
# 5  0.461856    0.679583 -24.755340       0.740       0.695          0
#
#       field  nobs  mobs    B-V  ...  e_zmag  zchi  zcontrib  nstat    Jmag  \
# 0  20131184     5    20  0.727  ...   0.012  8.01        0f      0  12.332
# 2  20161306     4    18  0.868  ...   0.008  0.42        07      2  12.979
# 3  20161423     3    10  0.807  ...   0.009  0.78        0f      0  14.361
# 4  20161059     6    29  0.790  ...   0.008  0.30        0f      0  14.155
# 5  20161306     2     6  1.046  ...   0.022  0.56        04     10  15.148
#
#    e_Jmag    Hmag  e_Hmag    Kmag  e_Kmag
# 0   0.023  11.980   0.020  11.909   0.023
# ...
